# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#create sample messy employee data
data = {
    "EmpId": [101, 102, "103", 104, 105, 106, 107, 108, 109, 110],
    "fullName": [
        "  Alice Johnson  ", "MICHEAL smith", "sarah lee", "David-Kim", None, "john brown",
        "Emma Wilson", "TOM  davis", "Jane Miller", "Chris taylor"
    ], 
     "Dept": ["IT", "hr", "Mktng", "IT", "Customer Care", "marketing", "Finance", None, "HR", "marketing"],
    "Age": [29, "thirty-five", 26, 31, 42, 27, 33, 30, None, 28],
    "Salary($)": ["$5500.50", "4800", "4200.75", "NaN", "6100", "4,300", "5800", "5000", "4700.0", "4400"],
    "JoinDate": [
        "2021/04/12", "2020/11/01", "2022/01/18", "2019/9/25", "2018/07/05", 
        "2021/10/14", "2019/12/01", "2020/03/22", "2021/05/10", "2022/02/05"
    ],
    "Performance": [87, "73", 90, 65, 82, 75, 88, None, "79%", "91"],
    "Remote?": ["Yes", "No", "Y", "N", "yes", "no", "Y", "Yes", None, "True"]
}

# %%
df = pd.DataFrame(data)

df.to_csv("employee_dataset.csv", index=False)

df = pd.read_csv("employee_dataset.csv")

df
# Out:
#    EmpId           fullName           Dept          Age Salary($)    JoinDate  \
# 0    101    Alice Johnson               IT           29  $5500.50  2021/04/12
# 1    102      MICHEAL smith             hr  thirty-five      4800  2020/11/01
# 2    103          sarah lee          Mktng           26   4200.75  2022/01/18
# 3    104          David-Kim             IT           31       NaN   2019/9/25
# 4    105                NaN  Customer Care           42      6100  2018/07/05
# 5    106         john brown      marketing           27     4,300  2021/10/14
# 6    107        Emma Wilson        Finance           33      5800  2019/12/01
# 7    108         TOM  davis            NaN           30      5000  2020/03/22
# 8    109        Jane Miller             HR          NaN    4700.0  2021/05/10
# 9    110       Chris taylor      marketing           28      4400  2022/02/05
#
#   Performance Remote?
# 0          87     Yes
# 1          73      No
# 2          90       Y
# 3          65       N
# 4          82     yes
# 5          75      no
# 6          88       Y
# 7         NaN     Yes
# 8         79%     NaN
# 9          91    True

# %%
#get the dataframe shapes
df.shape
# Out:
# (10, 8)

# %%
#get the information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EmpId        10 non-null     int64
#  1   fullName     9 non-null      object
#  2   Dept         9 non-null      object
#  3   Age          9 non-null      object
#  4   Salary($)    9 non-null      object
#  5   JoinDate     10 non-null     object
#  6   Performance  9 non-null      object
#  7   Remote?      9 non-null      object
# dtypes: int64(1), object(7)
# memory usage: 768.0+ bytes

# %%
#get first five rows of the dataset
df.head()
# Out:
#    EmpId           fullName           Dept          Age Salary($)    JoinDate  \
# 0    101    Alice Johnson               IT           29  $5500.50  2021/04/12
# 1    102      MICHEAL smith             hr  thirty-five      4800  2020/11/01
# 2    103          sarah lee          Mktng           26   4200.75  2022/01/18
# 3    104          David-Kim             IT           31       NaN   2019/9/25
# 4    105                NaN  Customer Care           42      6100  2018/07/05
#
#   Performance Remote?
# 0          87     Yes
# 1          73      No
# 2          90       Y
# 3          65       N
# 4          82     yes

# %%
#get columns for the dataset
df.columns
# Out:
# Index(['EmpId', 'fullName', 'Dept', 'Age', 'Salary($)', 'JoinDate',
#        'Performance', 'Remote?'],
#       dtype='object')

# %%
#get missing values
df.isnull().sum()
# Out:
# EmpId          0
# fullName       1
# Dept           1
# Age            1
# Salary($)      1
# JoinDate       0
# Performance    1
# Remote?        1
# dtype: int64

# %%
#get uniqueness of the dataset
print(df["Dept"].unique())
print(df['Age'].unique())
print(df['Remote?'].unique())
# Out:
# ['IT' 'hr' 'Mktng' 'Customer Care' 'marketing' 'Finance' nan 'HR']
# ['29' 'thirty-five' '26' '31' '42' '27' '33' '30' nan '28']
# ['Yes' 'No' 'Y' 'N' 'yes' 'no' nan 'True']

# %%
#access series data
df["Salary($)"].tolist()
# Out:
# ['$5500.50',
#  '4800',
#  '4200.75',
#  nan,
#  '6100',
#  '4,300',
#  '5800',
#  '5000',
#  '4700.0',
#  '4400']

# %%
df['fullName'].tolist()
# Out:
# ['  Alice Johnson  ',
#  'MICHEAL smith',
#  'sarah lee',
#  'David-Kim',
#  nan,
#  'john brown',
#  'Emma Wilson',
#  'TOM  davis',
#  'Jane Miller',
#  'Chris taylor']

# %%
df['Salary($)'].head()
# Out:
# 0    $5500.50
# 1        4800
# 2     4200.75
# 3         NaN
# 4        6100
# Name: Salary($), dtype: object

# %%
#start cleaning inconsistence valus
#rename inconsistence columns
df.rename(columns={
    'EmpId': 'emp_id',
    'fullName': 'full_name',
    'Dept': 'department',
    'Age': 'age',
    'Salary($)': 'salary',
    'JoinDate': 'join_date',
    'Performance': 'performance',
    'Remote?': 'remote'
}, inplace=True)

df
# Out:
#    emp_id          full_name     department          age    salary  \
# 0     101    Alice Johnson               IT           29  $5500.50
# 1     102      MICHEAL smith             hr  thirty-five      4800
# 2     103          sarah lee          Mktng           26   4200.75
# 3     104          David-Kim             IT           31       NaN
# 4     105                NaN  Customer Care           42      6100
# 5     106         john brown      marketing           27     4,300
# 6     107        Emma Wilson        Finance           33      5800
# 7     108         TOM  davis            NaN           30      5000
# 8     109        Jane Miller             HR          NaN    4700.0
# 9     110       Chris taylor      marketing           28      4400
#
#     join_date performance remote
# 0  2021/04/12          87    Yes
# 1  2020/11/01          73     No
# 2  2022/01/18          90      Y
# 3   2019/9/25          65      N
# 4  2018/07/05          82    yes
# 5  2021/10/14          75     no
# 6  2019/12/01          88      Y
# 7  2020/03/22         NaN    Yes
# 8  2021/05/10         79%    NaN
# 9  2022/02/05          91   True

# %%
df['full_name'] = df['full_name'].str.strip()
df['full_name'] = df['full_name'].str.title()
df['full_name'] = df['full_name'].str.replace(r"\s+", " ", regex=True)
df['full_name'] = df['full_name'].str.replace(r"-", " ")
df['full_name'].tolist()
# Out:
# ['Alice Johnson',
#  'Micheal Smith',
#  'Sarah Lee',
#  'David Kim',
#  nan,
#  'John Brown',
#  'Emma Wilson',
#  'Tom Davis',
#  'Jane Miller',
#  'Chris Taylor']

# %%
#clean inconsistent values on department
df["department"].replace({
    "hr": "HR",
    "Mktng": "Marketing",
    "marketing": "Marketing"
}, inplace=True)

df
# Out:
# C:\Users\ola-dev\AppData\Local\Temp\ipykernel_12164\4184915569.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["department"].replace({
#    emp_id      full_name     department          age    salary   join_date  \
# 0     101  Alice Johnson             IT           29  $5500.50  2021/04/12
# 1     102  Micheal Smith             HR  thirty-five      4800  2020/11/01
# 2     103      Sarah Lee      Marketing           26   4200.75  2022/01/18
# 3     104      David Kim             IT           31       NaN   2019/9/25
# 4     105            NaN  Customer Care           42      6100  2018/07/05
# 5     106     John Brown      Marketing           27     4,300  2021/10/14
# 6     107    Emma Wilson        Finance           33      5800  2019/12/01
# 7     108      Tom Davis            NaN           30      5000  2020/03/22
# 8     109    Jane Miller             HR          NaN    4700.0  2021/05/10
# 9     110   Chris Taylor      Marketing           28      4400  2022/02/05
#
#   performance remote
# 0          87    Yes
# 1          73     No
# 2          90      Y
# 3          65      N
# 4          82    yes
# 5          75     no
# 6          88      Y
# 7         NaN    Yes
# 8         79%    NaN
# 9          91   True

# %%
#clean inconsistent values on age
def clean_age(value):
    if value == "thirty-five":
        return 35
    elif isinstance(value, (int, float)):
        return value
    elif isinstance(value, str) and value.isdigit():
        return int(value)
    else:
        return np.nan

df['age'] = df['age'].apply(clean_age)

df['age']
# Out:
# 0    29.0
# 1    35.0
# 2    26.0
# 3    31.0
# 4    42.0
# 5    27.0
# 6    33.0
# 7    30.0
# 8     NaN
# 9    28.0
# Name: age, dtype: float64

# %%
#clean inconsistent value on salary
df["salary"] = (
    df["salary"]
    .astype(str)
    .replace(r"[$,]", "", regex=True)
    .replace("NAN", np.nan)
    .astype(float)
)

df["salary"]
# Out:
# 0    5500.50
# 1    4800.00
# 2    4200.75
# 3        NaN
# 4    6100.00
# 5    4300.00
# 6    5800.00
# 7    5000.00
# 8    4700.00
# 9    4400.00
# Name: salary, dtype: float64

# %%
df['join_date'] = pd.to_datetime(df['join_date'], errors='coerce')
df['join_date']
# Out:
# 0   2021-04-12
# 1   2020-11-01
# 2   2022-01-18
# 3   2019-09-25
# 4   2018-07-05
# 5   2021-10-14
# 6   2019-12-01
# 7   2020-03-22
# 8   2021-05-10
# 9   2022-02-05
# Name: join_date, dtype: datetime64[ns]

# %%
#clean inconsistent value in performance
df['performance'] = (
    df['performance']
    .astype(str)
    .str.replace('%', '', regex=False)
    .replace("None", np.nan)
    .astype(float)
)

df['performance']
# Out:
# 0    87.0
# 1    73.0
# 2    90.0
# 3    65.0
# 4    82.0
# 5    75.0
# 6    88.0
# 7     NaN
# 8    79.0
# 9    91.0
# Name: performance, dtype: float64

# %%
#clean inconsistent value on remote
df['remote'].replace({
    'Y': 'Yes',
    'N': 'No',
    'yes': 'Yes',
    'no': 'No',
    'True': 'Yes',
    None: np.nan
}, inplace=True)

df['remote']
# Out:
# C:\Users\ola-dev\AppData\Local\Temp\ipykernel_12164\481794493.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['remote'].replace({
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# 5     No
# 6    Yes
# 7    Yes
# 8    NaN
# 9    Yes
# Name: remote, dtype: object

# %%
#clean inconsistent empid value
df["emp_id"] = pd.to_numeric(df["emp_id"], errors='coerce')
df['emp_id']
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# 5    106
# 6    107
# 7    108
# 8    109
# 9    110
# Name: emp_id, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   emp_id       10 non-null     int64
#  1   full_name    9 non-null      object
#  2   department   9 non-null      object
#  3   age          9 non-null      float64
#  4   salary       9 non-null      float64
#  5   join_date    10 non-null     datetime64[ns]
#  6   performance  9 non-null      float64
#  7   remote       9 non-null      object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 768.0+ bytes

# %%
#handling missing value
df['full_name'] = df['full_name'].fillna("Unknown")
df['full_name']
# Out:
# 0    Alice Johnson
# 1    Micheal Smith
# 2        Sarah Lee
# 3        David Kim
# 4          Unknown
# 5       John Brown
# 6      Emma Wilson
# 7        Tom Davis
# 8      Jane Miller
# 9     Chris Taylor
# Name: full_name, dtype: object

# %%
df['department'] = df['department'].fillna(df['department'].mode()[0])
df['department']
# Out:
# 0               IT
# 1               HR
# 2        Marketing
# 3               IT
# 4    Customer Care
# 5        Marketing
# 6          Finance
# 7        Marketing
# 8               HR
# 9        Marketing
# Name: department, dtype: object

# %%
df['age'] = df['age'].fillna(df['age'].median())
df['age']
# Out:
# 0    29.0
# 1    35.0
# 2    26.0
# 3    31.0
# 4    42.0
# 5    27.0
# 6    33.0
# 7    30.0
# 8    30.0
# 9    28.0
# Name: age, dtype: float64

# %%
df['salary'] = df['salary'].fillna(df['salary'].median())
df['salary']
# Out:
# 0    5500.50
# 1    4800.00
# 2    4200.75
# 3    4800.00
# 4    6100.00
# 5    4300.00
# 6    5800.00
# 7    5000.00
# 8    4700.00
# 9    4400.00
# Name: salary, dtype: float64

# %%
df['performance'] = df['performance'].fillna(df['performance'].median())
df['performance']
# Out:
# 0    87.0
# 1    73.0
# 2    90.0
# 3    65.0
# 4    82.0
# 5    75.0
# 6    88.0
# 7    82.0
# 8    79.0
# 9    91.0
# Name: performance, dtype: float64

# %%
df['remote'] = df['remote'].fillna(df['remote'].mode()[0])
df['remote']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4    Yes
# 5     No
# 6    Yes
# 7    Yes
# 8    Yes
# 9    Yes
# Name: remote, dtype: object

# %%
#working with filter data
df.head()
# Out:
#    emp_id      full_name     department   age   salary  join_date  \
# 0     101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 1     102  Micheal Smith             HR  35.0  4800.00 2020-11-01
# 2     103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 3     104      David Kim             IT  31.0  4800.00 2019-09-25
# 4     105        Unknown  Customer Care  42.0  6100.00 2018-07-05
#
#    performance remote
# 0         87.0    Yes
# 1         73.0     No
# 2         90.0    Yes
# 3         65.0     No
# 4         82.0    Yes

# %%
df['full_name']
# Out:
# 0    Alice Johnson
# 1    Micheal Smith
# 2        Sarah Lee
# 3        David Kim
# 4          Unknown
# 5       John Brown
# 6      Emma Wilson
# 7        Tom Davis
# 8      Jane Miller
# 9     Chris Taylor
# Name: full_name, dtype: object

# %%
df[['full_name', 'department', 'salary']]
# Out:
#        full_name     department   salary
# 0  Alice Johnson             IT  5500.50
# 1  Micheal Smith             HR  4800.00
# 2      Sarah Lee      Marketing  4200.75
# 3      David Kim             IT  4800.00
# 4        Unknown  Customer Care  6100.00
# 5     John Brown      Marketing  4300.00
# 6    Emma Wilson        Finance  5800.00
# 7      Tom Davis      Marketing  5000.00
# 8    Jane Miller             HR  4700.00
# 9   Chris Taylor      Marketing  4400.00

# %%
df.iloc[0:3]
# Out:
#    emp_id      full_name department   age   salary  join_date  performance  \
# 0     101  Alice Johnson         IT  29.0  5500.50 2021-04-12         87.0
# 1     102  Micheal Smith         HR  35.0  4800.00 2020-11-01         73.0
# 2     103      Sarah Lee  Marketing  26.0  4200.75 2022-01-18         90.0
#
#   remote
# 0    Yes
# 1     No
# 2    Yes

# %%
df.iloc[0:3, 0:3]
# Out:
#    emp_id      full_name department
# 0     101  Alice Johnson         IT
# 1     102  Micheal Smith         HR
# 2     103      Sarah Lee  Marketing

# %%
df.loc[df['salary'] > 5000]
# Out:
#    emp_id      full_name     department   age  salary  join_date  performance  \
# 0     101  Alice Johnson             IT  29.0  5500.5 2021-04-12         87.0
# 4     105        Unknown  Customer Care  42.0  6100.0 2018-07-05         82.0
# 6     107    Emma Wilson        Finance  33.0  5800.0 2019-12-01         88.0
#
#   remote
# 0    Yes
# 4    Yes
# 6    Yes

# %%
df.loc[df['salary'] > 5000, ['full_name', 'department']]
# Out:
#        full_name     department
# 0  Alice Johnson             IT
# 4        Unknown  Customer Care
# 6    Emma Wilson        Finance

# %%
df[df['department'] == 'IT']
# Out:
#    emp_id      full_name department   age  salary  join_date  performance  \
# 0     101  Alice Johnson         IT  29.0  5500.5 2021-04-12         87.0
# 3     104      David Kim         IT  31.0  4800.0 2019-09-25         65.0
#
#   remote
# 0    Yes
# 3     No

# %%
df[df['age'] > 25]
# Out:
#    emp_id      full_name     department   age   salary  join_date  \
# 0     101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 1     102  Micheal Smith             HR  35.0  4800.00 2020-11-01
# 2     103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 3     104      David Kim             IT  31.0  4800.00 2019-09-25
# 4     105        Unknown  Customer Care  42.0  6100.00 2018-07-05
# 5     106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 6     107    Emma Wilson        Finance  33.0  5800.00 2019-12-01
# 7     108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 8     109    Jane Miller             HR  30.0  4700.00 2021-05-10
# 9     110   Chris Taylor      Marketing  28.0  4400.00 2022-02-05
#
#    performance remote
# 0         87.0    Yes
# 1         73.0     No
# 2         90.0    Yes
# 3         65.0     No
# 4         82.0    Yes
# 5         75.0     No
# 6         88.0    Yes
# 7         82.0    Yes
# 8         79.0    Yes
# 9         91.0    Yes

# %%
df[df['department'] != 'HR']
# Out:
#    emp_id      full_name     department   age   salary  join_date  \
# 0     101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 2     103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 3     104      David Kim             IT  31.0  4800.00 2019-09-25
# 4     105        Unknown  Customer Care  42.0  6100.00 2018-07-05
# 5     106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 6     107    Emma Wilson        Finance  33.0  5800.00 2019-12-01
# 7     108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 9     110   Chris Taylor      Marketing  28.0  4400.00 2022-02-05
#
#    performance remote
# 0         87.0    Yes
# 2         90.0    Yes
# 3         65.0     No
# 4         82.0    Yes
# 5         75.0     No
# 6         88.0    Yes
# 7         82.0    Yes
# 9         91.0    Yes

# %%
df[
    (df['salary'] > 4000) & (df['remote'] == 'Yes')
]
# Out:
#    emp_id      full_name     department   age   salary  join_date  \
# 0     101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 2     103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 4     105        Unknown  Customer Care  42.0  6100.00 2018-07-05
# 6     107    Emma Wilson        Finance  33.0  5800.00 2019-12-01
# 7     108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 8     109    Jane Miller             HR  30.0  4700.00 2021-05-10
# 9     110   Chris Taylor      Marketing  28.0  4400.00 2022-02-05
#
#    performance remote
# 0         87.0    Yes
# 2         90.0    Yes
# 4         82.0    Yes
# 6         88.0    Yes
# 7         82.0    Yes
# 8         79.0    Yes
# 9         91.0    Yes

# %%
df[df['department'].isin(['IT', 'Finance'])]
# Out:
#    emp_id      full_name department   age  salary  join_date  performance  \
# 0     101  Alice Johnson         IT  29.0  5500.5 2021-04-12         87.0
# 3     104      David Kim         IT  31.0  4800.0 2019-09-25         65.0
# 6     107    Emma Wilson    Finance  33.0  5800.0 2019-12-01         88.0
#
#   remote
# 0    Yes
# 3     No
# 6    Yes

# %%
df[df['full_name'].str.contains('john', case=False)]
# Out:
#    emp_id      full_name department   age  salary  join_date  performance  \
# 0     101  Alice Johnson         IT  29.0  5500.5 2021-04-12         87.0
# 5     106     John Brown  Marketing  27.0  4300.0 2021-10-14         75.0
#
#   remote
# 0    Yes
# 5     No

# %%
df[df['department'].str.startswith('M')]
# Out:
#    emp_id     full_name department   age   salary  join_date  performance  \
# 2     103     Sarah Lee  Marketing  26.0  4200.75 2022-01-18         90.0
# 5     106    John Brown  Marketing  27.0  4300.00 2021-10-14         75.0
# 7     108     Tom Davis  Marketing  30.0  5000.00 2020-03-22         82.0
# 9     110  Chris Taylor  Marketing  28.0  4400.00 2022-02-05         91.0
#
#   remote
# 2    Yes
# 5     No
# 7    Yes
# 9    Yes

# %%
#working with sorting
df.sort_values('salary', ascending=False)
# Out:
#    emp_id      full_name     department   age   salary  join_date  \
# 4     105        Unknown  Customer Care  42.0  6100.00 2018-07-05
# 6     107    Emma Wilson        Finance  33.0  5800.00 2019-12-01
# 0     101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 7     108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 1     102  Micheal Smith             HR  35.0  4800.00 2020-11-01
# 3     104      David Kim             IT  31.0  4800.00 2019-09-25
# 8     109    Jane Miller             HR  30.0  4700.00 2021-05-10
# 9     110   Chris Taylor      Marketing  28.0  4400.00 2022-02-05
# 5     106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 2     103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
#
#    performance remote
# 4         82.0    Yes
# 6         88.0    Yes
# 0         87.0    Yes
# 7         82.0    Yes
# 1         73.0     No
# 3         65.0     No
# 8         79.0    Yes
# 9         91.0    Yes
# 5         75.0     No
# 2         90.0    Yes

# %%
df.sort_values('performance', ascending=False).head()
# Out:
#    emp_id      full_name department   age   salary  join_date  performance  \
# 9     110   Chris Taylor  Marketing  28.0  4400.00 2022-02-05         91.0
# 2     103      Sarah Lee  Marketing  26.0  4200.75 2022-01-18         90.0
# 6     107    Emma Wilson    Finance  33.0  5800.00 2019-12-01         88.0
# 0     101  Alice Johnson         IT  29.0  5500.50 2021-04-12         87.0
# 7     108      Tom Davis  Marketing  30.0  5000.00 2020-03-22         82.0
#
#   remote
# 9    Yes
# 2    Yes
# 6    Yes
# 0    Yes
# 7    Yes

# %%
df.sort_values(['department', 'salary'], ascending=[True, False])
# Out:
#    emp_id      full_name     department   age   salary  join_date  \
# 4     105        Unknown  Customer Care  42.0  6100.00 2018-07-05
# 6     107    Emma Wilson        Finance  33.0  5800.00 2019-12-01
# 1     102  Micheal Smith             HR  35.0  4800.00 2020-11-01
# 8     109    Jane Miller             HR  30.0  4700.00 2021-05-10
# 0     101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 3     104      David Kim             IT  31.0  4800.00 2019-09-25
# 7     108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 9     110   Chris Taylor      Marketing  28.0  4400.00 2022-02-05
# 5     106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 2     103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
#
#    performance remote
# 4         82.0    Yes
# 6         88.0    Yes
# 1         73.0     No
# 8         79.0    Yes
# 0         87.0    Yes
# 3         65.0     No
# 7         82.0    Yes
# 9         91.0    Yes
# 5         75.0     No
# 2         90.0    Yes

# %%
#working with values count
df['department'].value_counts()
# Out:
# department
# Marketing        4
# IT               2
# HR               2
# Customer Care    1
# Finance          1
# Name: count, dtype: int64

# %%
df['department'].value_counts(normalize=True)*100
# Out:
# department
# Marketing        40.0
# IT               20.0
# HR               20.0
# Customer Care    10.0
# Finance          10.0
# Name: proportion, dtype: float64

# %%
df['remote'].value_counts(normalize=True)*100
# Out:
# remote
# Yes    70.0
# No     30.0
# Name: proportion, dtype: float64

# %%
#working with merge
data1 = {
    "department": ["IT", "HR", "Finance", "Marketing", "R&D", "Operations", "Sales", "Logistics", "Procurement", "Customer Service"],
    "manager": [
        "Tom Hanks", "Susan Lee", "Robert Miles", 
        "Mark Chan", "Sarah Connor", "James Nwosu", "Adaeze Obi", 
        "Daniel Smith", "Amina Yusuf", "Grace Ojo"
    ],
    "department_budget": [200000, 150000, 250000, 180000, 300000, 220000, 210000, 195000, 230000, 170000],
    "office_location": [
        "Lagos", "Abuja", "Port Harcourt", "Ibadan", "Enugu", "Kano",
        "Lagos", "Calabar", "Abuja", "Kano"
    ]
}

df1 = pd.DataFrame(data1)
df1.to_csv("department_data.csv", index=False)

df1 = pd.read_csv("department_data.csv")
df1.head(10)
# Out:
#          department       manager  department_budget office_location
# 0                IT     Tom Hanks             200000           Lagos
# 1                HR     Susan Lee             150000           Abuja
# 2           Finance  Robert Miles             250000   Port Harcourt
# 3         Marketing     Mark Chan             180000          Ibadan
# 4               R&D  Sarah Connor             300000           Enugu
# 5        Operations   James Nwosu             220000            Kano
# 6             Sales    Adaeze Obi             210000           Lagos
# 7         Logistics  Daniel Smith             195000         Calabar
# 8       Procurement   Amina Yusuf             230000           Abuja
# 9  Customer Service     Grace Ojo             170000            Kano

# %%
merge_df = pd.merge(df, df1, how='inner')
merge_df
# Out:
#    emp_id      full_name department   age   salary  join_date  performance  \
# 0     101  Alice Johnson         IT  29.0  5500.50 2021-04-12         87.0
# 1     102  Micheal Smith         HR  35.0  4800.00 2020-11-01         73.0
# 2     103      Sarah Lee  Marketing  26.0  4200.75 2022-01-18         90.0
# 3     104      David Kim         IT  31.0  4800.00 2019-09-25         65.0
# 4     106     John Brown  Marketing  27.0  4300.00 2021-10-14         75.0
# 5     107    Emma Wilson    Finance  33.0  5800.00 2019-12-01         88.0
# 6     108      Tom Davis  Marketing  30.0  5000.00 2020-03-22         82.0
# 7     109    Jane Miller         HR  30.0  4700.00 2021-05-10         79.0
# 8     110   Chris Taylor  Marketing  28.0  4400.00 2022-02-05         91.0
#
#   remote       manager  department_budget office_location
# 0    Yes     Tom Hanks             200000           Lagos
# 1     No     Susan Lee             150000           Abuja
# 2    Yes     Mark Chan             180000          Ibadan
# 3     No     Tom Hanks             200000           Lagos
# 4     No     Mark Chan             180000          Ibadan
# 5    Yes  Robert Miles             250000   Port Harcourt
# 6    Yes     Mark Chan             180000          Ibadan
# 7    Yes     Susan Lee             150000           Abuja
# 8    Yes     Mark Chan             180000          Ibadan

# %%
left_df = pd.merge(df, df1, how='left')
left_df
# Out:
#    emp_id      full_name     department   age   salary  join_date  \
# 0     101  Alice Johnson             IT  29.0  5500.50 2021-04-12
# 1     102  Micheal Smith             HR  35.0  4800.00 2020-11-01
# 2     103      Sarah Lee      Marketing  26.0  4200.75 2022-01-18
# 3     104      David Kim             IT  31.0  4800.00 2019-09-25
# 4     105        Unknown  Customer Care  42.0  6100.00 2018-07-05
# 5     106     John Brown      Marketing  27.0  4300.00 2021-10-14
# 6     107    Emma Wilson        Finance  33.0  5800.00 2019-12-01
# 7     108      Tom Davis      Marketing  30.0  5000.00 2020-03-22
# 8     109    Jane Miller             HR  30.0  4700.00 2021-05-10
# 9     110   Chris Taylor      Marketing  28.0  4400.00 2022-02-05
#
#    performance remote       manager  department_budget office_location
# 0         87.0    Yes     Tom Hanks           200000.0           Lagos
# 1         73.0     No     Susan Lee           150000.0           Abuja
# 2         90.0    Yes     Mark Chan           180000.0          Ibadan
# 3         65.0     No     Tom Hanks           200000.0           Lagos
# 4         82.0    Yes           NaN                NaN             NaN
# 5         75.0     No     Mark Chan           180000.0          Ibadan
# 6         88.0    Yes  Robert Miles           250000.0   Port Harcourt
# 7         82.0    Yes     Mark Chan           180000.0          Ibadan
# 8         79.0    Yes     Susan Lee           150000.0           Abuja
# 9         91.0    Yes     Mark Chan           180000.0          Ibadan

# %%
right_df = pd.merge(df, df1, how='right')
right_df
# Out:
#     emp_id      full_name        department   age   salary  join_date  \
# 0    101.0  Alice Johnson                IT  29.0  5500.50 2021-04-12
# 1    104.0      David Kim                IT  31.0  4800.00 2019-09-25
# 2    102.0  Micheal Smith                HR  35.0  4800.00 2020-11-01
# 3    109.0    Jane Miller                HR  30.0  4700.00 2021-05-10
# 4    107.0    Emma Wilson           Finance  33.0  5800.00 2019-12-01
# 5    103.0      Sarah Lee         Marketing  26.0  4200.75 2022-01-18
# 6    106.0     John Brown         Marketing  27.0  4300.00 2021-10-14
# 7    108.0      Tom Davis         Marketing  30.0  5000.00 2020-03-22
# 8    110.0   Chris Taylor         Marketing  28.0  4400.00 2022-02-05
# 9      NaN            NaN               R&D   NaN      NaN        NaT
# 10     NaN            NaN        Operations   NaN      NaN        NaT
# 11     NaN            NaN             Sales   NaN      NaN        NaT
# 12     NaN            NaN         Logistics   NaN      NaN        NaT
# 13     NaN            NaN       Procurement   NaN      NaN        NaT
# 14     NaN            NaN  Customer Service   NaN      NaN        NaT
#
#     performance remote       manager  department_budget office_location
# 0          87.0    Yes     Tom Hanks             200000           Lagos
# 1          65.0     No     Tom Hanks             200000           Lagos
# 2          73.0     No     Susan Lee             150000           Abuja
# 3          79.0    Yes     Susan Lee             150000           Abuja
# 4          88.0    Yes  Robert Miles             250000   Port Harcourt
# 5          90.0    Yes     Mark Chan             180000          Ibadan
# 6          75.0     No     Mark Chan             180000          Ibadan
# 7          82.0    Yes     Mark Chan             180000          Ibadan
# 8          91.0    Yes     Mark Chan             180000          Ibadan
# 9           NaN    NaN  Sarah Connor             300000           Enugu
# 10          NaN    NaN   James Nwosu             220000            Kano
# 11          NaN    NaN    Adaeze Obi             210000           Lagos
# 12          NaN    NaN  Daniel Smith             195000         Calabar
# 13          NaN    NaN   Amina Yusuf             230000           Abuja
# 14          NaN    NaN     Grace Ojo             170000            Kano

# %%
outter_df = pd.merge(df, df1, how='outer')
outter_df
# Out:
#     emp_id      full_name        department   age   salary  join_date  \
# 0    105.0        Unknown     Customer Care  42.0  6100.00 2018-07-05
# 1      NaN            NaN  Customer Service   NaN      NaN        NaT
# 2    107.0    Emma Wilson           Finance  33.0  5800.00 2019-12-01
# 3    102.0  Micheal Smith                HR  35.0  4800.00 2020-11-01
# 4    109.0    Jane Miller                HR  30.0  4700.00 2021-05-10
# 5    101.0  Alice Johnson                IT  29.0  5500.50 2021-04-12
# 6    104.0      David Kim                IT  31.0  4800.00 2019-09-25
# 7      NaN            NaN         Logistics   NaN      NaN        NaT
# 8    103.0      Sarah Lee         Marketing  26.0  4200.75 2022-01-18
# 9    106.0     John Brown         Marketing  27.0  4300.00 2021-10-14
# 10   108.0      Tom Davis         Marketing  30.0  5000.00 2020-03-22
# 11   110.0   Chris Taylor         Marketing  28.0  4400.00 2022-02-05
# 12     NaN            NaN        Operations   NaN      NaN        NaT
# 13     NaN            NaN       Procurement   NaN      NaN        NaT
# 14     NaN            NaN               R&D   NaN      NaN        NaT
# 15     NaN            NaN             Sales   NaN      NaN        NaT
#
#     performance remote       manager  department_budget office_location
# 0          82.0    Yes           NaN                NaN             NaN
# 1           NaN    NaN     Grace Ojo           170000.0            Kano
# 2          88.0    Yes  Robert Miles           250000.0   Port Harcourt
# 3          73.0     No     Susan Lee           150000.0           Abuja
# 4          79.0    Yes     Susan Lee           150000.0           Abuja
# 5          87.0    Yes     Tom Hanks           200000.0           Lagos
# 6          65.0     No     Tom Hanks           200000.0           Lagos
# 7           NaN    NaN  Daniel Smith           195000.0         Calabar
# 8          90.0    Yes     Mark Chan           180000.0          Ibadan
# 9          75.0     No     Mark Chan           180000.0          Ibadan
# 10         82.0    Yes     Mark Chan           180000.0          Ibadan
# 11         91.0    Yes     Mark Chan           180000.0          Ibadan
# 12          NaN    NaN   James Nwosu           220000.0            Kano
# 13          NaN    NaN   Amina Yusuf           230000.0           Abuja
# 14          NaN    NaN  Sarah Connor           300000.0           Enugu
# 15          NaN    NaN    Adaeze Obi           210000.0           Lagos

# %%
print(merge_df['salary'].mean())
# Out:
# 4833.472222222223

# %%
#working with groupby
#average salary by department
merge_df.groupby("department")["salary"].mean().sort_values(ascending=False)
# Out:
# department
# Finance      5800.0000
# IT           5150.2500
# HR           4750.0000
# Marketing    4475.1875
# Name: salary, dtype: float64

# %%
#average performance by department
merge_df.groupby("department")["performance"].mean().sort_values(ascending=False)
# Out:
# department
# Finance      88.0
# Marketing    84.5
# HR           76.0
# IT           76.0
# Name: performance, dtype: float64

# %%
#average performance by department and remote
merge_df.groupby(["department", "remote"])["performance"].mean().sort_values(ascending=False)
# Out:
# department  remote
# Finance     Yes       88.000000
# Marketing   Yes       87.666667
# IT          Yes       87.000000
# HR          Yes       79.000000
# Marketing   No        75.000000
# HR          No        73.000000
# IT          No        65.000000
# Name: performance, dtype: float64

# %%
#working with multiple aggregation
merge_df.groupby("department")["salary"].agg({'mean', 'count', 'min', 'max'})
# Out:
#                max  count       mean      min
# department
# Finance     5800.0      1  5800.0000  5800.00
# HR          4800.0      2  4750.0000  4700.00
# IT          5500.5      2  5150.2500  4800.00
# Marketing   5000.0      4  4475.1875  4200.75

# %%
#working with multiple columns apply to several
merge_df.groupby("department")[['salary', 'performance']].mean().sort_values(by='salary', ascending=False)
# Out:
#                salary  performance
# department
# Finance     5800.0000         88.0
# IT          5150.2500         76.0
# HR          4750.0000         76.0
# Marketing   4475.1875         84.5

# %%
#working with multiple aggregation
merge_df.groupby("department").agg(
    average_salary=('salary', 'mean'),
    highest_salary=('salary', 'max'),
    lowest_salary=('salary', 'min'),
    employee_count=('salary', 'count')
)
# Out:
#             average_salary  highest_salary  lowest_salary  employee_count
# department
# Finance          5800.0000          5800.0        5800.00               1
# HR               4750.0000          4800.0        4700.00               2
# IT               5150.2500          5500.5        4800.00               2
# Marketing        4475.1875          5000.0        4200.75               4

# %%
#working with multiple aggregation
merge_df.groupby("department").agg(
    average_salary=('salary', 'mean'),
    avg_performance=('performance', 'mean'),
    total_employee=('emp_id', 'count')
)
# Out:
#             average_salary  avg_performance  total_employee
# department
# Finance          5800.0000             88.0               1
# HR               4750.0000             76.0               2
# IT               5150.2500             76.0               2
# Marketing        4475.1875             84.5               4

# %%
#group column by salary using reset_index
merge_df.groupby("department")["salary"].mean().reset_index()
# Out:
#   department     salary
# 0    Finance  5800.0000
# 1         HR  4750.0000
# 2         IT  5150.2500
# 3  Marketing  4475.1875

# %%
merge_df.groupby("department")["salary"].apply(lambda x: x.std())
# Out:
# department
# Finance             NaN
# HR            70.710678
# IT           495.328300
# Marketing    359.206497
# Name: salary, dtype: float64

# %%
merge_df.groupby("department").filter(lambda x: x['salary'].mean() > 5000)
# Out:
#    emp_id      full_name department   age  salary  join_date  performance  \
# 0     101  Alice Johnson         IT  29.0  5500.5 2021-04-12         87.0
# 3     104      David Kim         IT  31.0  4800.0 2019-09-25         65.0
# 5     107    Emma Wilson    Finance  33.0  5800.0 2019-12-01         88.0
#
#   remote       manager  department_budget office_location
# 0    Yes     Tom Hanks             200000           Lagos
# 3     No     Tom Hanks             200000           Lagos
# 5    Yes  Robert Miles             250000   Port Harcourt

# %%
merge_df['department_avg_salary'] = merge_df.groupby('department')['salary'].transform('mean')
merge_df
# Out:
#    emp_id      full_name department   age   salary  join_date  performance  \
# 0     101  Alice Johnson         IT  29.0  5500.50 2021-04-12         87.0
# 1     102  Micheal Smith         HR  35.0  4800.00 2020-11-01         73.0
# 2     103      Sarah Lee  Marketing  26.0  4200.75 2022-01-18         90.0
# 3     104      David Kim         IT  31.0  4800.00 2019-09-25         65.0
# 4     106     John Brown  Marketing  27.0  4300.00 2021-10-14         75.0
# 5     107    Emma Wilson    Finance  33.0  5800.00 2019-12-01         88.0
# 6     108      Tom Davis  Marketing  30.0  5000.00 2020-03-22         82.0
# 7     109    Jane Miller         HR  30.0  4700.00 2021-05-10         79.0
# 8     110   Chris Taylor  Marketing  28.0  4400.00 2022-02-05         91.0
#
#   remote       manager  department_budget office_location  \
# 0    Yes     Tom Hanks             200000           Lagos
# 1     No     Susan Lee             150000           Abuja
# 2    Yes     Mark Chan             180000          Ibadan
# 3     No     Tom Hanks             200000           Lagos
# 4     No     Mark Chan             180000          Ibadan
# 5    Yes  Robert Miles             250000   Port Harcourt
# 6    Yes     Mark Chan             180000          Ibadan
# 7    Yes     Susan Lee             150000           Abuja
# 8    Yes     Mark Chan             180000          Ibadan
#
#    department_avg_salary
# 0              5150.2500
# 1              4750.0000
# 2              4475.1875
# 3              5150.2500
# 4              4475.1875
# 5              5800.0000
# 6              4475.1875
# 7              4750.0000
# 8              4475.1875

# %%
merge_df.groupby('department')['salary'].apply(lambda x: x.max() - x.min())
# Out:
# department
# Finance        0.00
# HR           100.00
# IT           700.50
# Marketing    799.25
# Name: salary, dtype: float64

# %%
#visualize average salary by department
plt.bar(merge_df['department'], merge_df['salary'])
plt.title("Average salary by department")
plt.xlabel("Department")
plt.ylabel("Average Salary")
plt.grid(axis='y', linestyle="--", alpha=0.7)
plt.show()

# %%
#view proportion remote vs onsite
remote_status = ["Remote", "Onsite"]
plt.pie(merge_df['remote'].value_counts(), labels=remote_status, autopct="%1.1f%%")
plt.title("Proportion value remote vs onsite")
plt.show()

# %%
#visual stack chart for department avg salary and department budget
plt.bar(merge_df['department'], merge_df['department_budget'], color='lightblue', label='Budget')
plt.bar(merge_df['department'], merge_df['department_avg_salary'], color='orange', label='Avg Salary')
plt.title("Average salary with department budget")
plt.xlabel("Department")
plt.ylabel("Avg Salary")
plt.show()

# %%
#visualize the employee performance overtime 
plt.plot(merge_df['full_name'], merge_df['performance'], marker="o", color='green')
plt.title('Employee performance over time')
plt.xlabel("Employee full name")
plt.ylabel('Employee performance')
plt.xticks(rotation=90)
plt.show()

# %%
#visualize relationship between salary and performance
plt.scatter(merge_df['salary'], merge_df['performance'], color='orange')
plt.title('Relationship between salary and performance')
plt.xlabel('Salary')
plt.ylabel('Performance')
plt.grid(linestyle="--", alpha=0.7)
plt.show()

# %%
#distribution of salary by employee
plt.hist(merge_df['salary'], bins=6, edgecolor='white', color='purple')
plt.title('Distribution of salary by employee')
plt.xlabel('Salary')
plt.ylabel('Number of employee')
plt.show()

# %%
#visualize the correlation matrix for numerical column 
num_cols = ['age', 'salary', 'performance', 'department_budget', 'department_avg_salary']

corr = merge_df[num_cols].corr()

sns.heatmap(corr, annot=True, cmap='vlag', fmt='.2f', linewidths='0.5', linecolor='blue')
plt.title("Correlation Matrix")
plt.show()

# %%
# merge_df.to_csv('cleaned_employee_dataset.csv', index=False)

# %%
#visualize the relationship for numerical columns using pair plot
sns.pairplot(merge_df[num_cols])
plt.suptitle("Relationship for numerical columns", y=1.05)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(merge_df['salary'])
plt.title('Box plot for salary')
plt.show()

# %%
plt.figure(figsize=(12, 6))
for i, col in enumerate(num_cols, 1):
    plt.subplot(2, 3, i)
    sns.boxplot(y=merge_df[col])
    plt.title(col)

plt.tight_layout()
plt.show()

# %%
#detect an outliers
num = merge_df[['age', 'salary', 'performance', 'department_budget', 'department_avg_salary']]

Q1 = num.quantile(0.25)
Q3 = num.quantile(0.75)

IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = (num < lower_bound) | (num > upper_bound)

print(outliers.sum())
# Out:
# age                      0
# salary                   0
# performance              0
# department_budget        1
# department_avg_salary    0
# dtype: int64

# %%
dept_count = merge_df['department'].value_counts()
fig = px.pie(
    values=dept_count.values,
    names=dept_count.index,
    title='Distribution of Employee by Department'
)
fig.show()

# %%
avg_salary = merge_df.groupby('department')['salary'].mean().sort_values()
fig = px.bar(
    x=avg_salary.values,
    y=avg_salary.index,
    orientation='h',
    title="Average Salary by Department"
)

fig.update_layout(xaxis_title='Salary', yaxis_title='department')

fig.show()

# %%
fig = px.histogram(
    merge_df,
    x='performance',
    nbins=6,
    title="Distribution of Employee by Performance"
)

fig.update_traces(
    marker_line_color='white',
    marker_line_width=1.5
)

fig.show()

# %%
location_count = merge_df['office_location'].value_counts()
fig = px.bar(
    x=location_count.index,
    y=location_count.values,
    title='Employee by Location'
)

fig.update_layout(xaxis_title='Location', yaxis_title='Count')

fig.show()

# %%
merge_df.to_csv('cleaned_employee_dataset.csv', index=False)
